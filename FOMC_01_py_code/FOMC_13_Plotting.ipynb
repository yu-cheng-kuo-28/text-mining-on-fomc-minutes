# %% [markdown]
# # (1) Preparation

# %% [markdown]
# ## 1-1 Update matplotlib to 3.4.2

# %%
# %pip install -U matplotlib
# Out:
# Requirement already up-to-date: matplotlib in c:\programdata\anaconda3\lib\site-packages (3.4.2)
# Requirement already satisfied, skipping upgrade: kiwisolver>=1.0.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied, skipping upgrade: pyparsing>=2.2.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib) (2.4.7)
# Requirement already satisfied, skipping upgrade: pillow>=6.2.0 in c:\programdata\anaconda3\lib\site-packages (from matplotlib) (8.0.1)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.7 in c:\programdata\anaconda3\lib\site-packages (from matplotlib) (2.8.1)
# Requirement already satisfied, skipping upgrade: cycler>=0.10 in c:\programdata\anaconda3\lib\site-packages (from matplotlib) (0.10.0)
# Requirement already satisfied, skipping upgrade: numpy>=1.16 in c:\programdata\anaconda3\lib\site-packages (from matplotlib) (1.19.2)
# Requirement already satisfied, skipping upgrade: six>=1.5 in c:\programdata\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.15.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## 1-2 Import Chinese font to matplotlib

# %%
# Python教學-如何解決 matplotlib 中文亂碼問題
# https://pyecontech.com/2020/03/27/python_matplotlib_chinese/

# %%
import matplotlib
print(matplotlib.__file__)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\__init__.py

# %%
import matplotlib.font_manager
 
a = sorted([f.name for f in matplotlib.font_manager.fontManager.ttflist])
 
for i in a:
    print(i)
# Out:
# Agency FB
# Agency FB
# Agency FB
# Agency FB
# Algerian
# Algerian
# Arial
# Arial
# Arial
# Arial
# Arial
# Arial
# Arial
# Arial
# Arial
# Arial
# Arial
# Arial
# Arial
# Arial
# Arial
# Arial
# Arial
# Arial
# Arial Rounded MT Bold
# Arial Rounded MT Bold
# Arvo
# Arvo
# Arvo
# Arvo
# Arvo
# Bahnschrift
# Bahnschrift
# Baskerville Old Face
# Baskerville Old Face
# Bauhaus 93
# Bauhaus 93
# Bell MT
# Bell MT
# Bell MT
# Bell MT
# Bell MT
# Bell MT
# Berlin Sans FB
# Berlin Sans FB
# Berlin Sans FB
# Berlin Sans FB
# Berlin Sans FB Demi
# Berlin Sans FB Demi
# Bernard MT Condensed
# Bernard MT Condensed
# Blackadder ITC
# Blackadder ITC
# Bodoni MT
# Bodoni MT
# Bodoni MT
# Bodoni MT
# Bodoni MT
# Bodoni MT
# Bodoni MT
# Bodoni MT
# Bodoni MT
# Bodoni MT
# Bodoni MT
# Bodoni MT
# Bodoni MT
# Bodoni MT
# Bodoni MT
# Bodoni MT
# Bodoni MT
# Bodoni MT
# Bodoni MT
# Bodoni MT
# Bodoni MT
# Bodoni MT
# Book Antiqua
# Book Antiqua
# Book Antiqua
# Book Antiqua
# Book Antiqua
# Book Antiqua
# Book Antiqua
# Book Antiqua
# Bookman Old Style
# Bookman Old Style
# Bookman Old Style
# Bookman Old Style
# Bookman Old Style
# Bookman Old Style
# Bookman Old Style
# Bookman Old Style
# Bookshelf Symbol 7
# Bookshelf Symbol 7
# Bradley Hand ITC
# Bradley Hand ITC
# Britannic Bold
# Britannic Bold
# Broadway
# Broadway
# Brush Script MT
# Brush Script MT
# Calibri
# Calibri
# Calibri
# Calibri
# Calibri
# Calibri
# Calibri
# Calibri
# Calibri
# Calibri
# Calibri
# Calibri
# Californian FB
# Californian FB
# Californian FB
# Californian FB
# Californian FB
# Californian FB
# Calisto MT
# Calisto MT
# Calisto MT
# Calisto MT
# Calisto MT
# Calisto MT
# Calisto MT
# Calisto MT
# Cambria
# Cambria
# Cambria
# Cambria
# Cambria
# Cambria
# Cambria
# Cambria
# Candara
# Candara
# Candara
# Candara
# Candara
# Candara
# Candara
# Candara
# Candara
# Candara
# Candara
# Candara
# Castellar
# Castellar
# Centaur
# Centaur
# Century
# Century
# Century Gothic
# Century Gothic
# Century Gothic
# Century Gothic
# Century Gothic
# Century Gothic
# Century Gothic
# Century Gothic
# Century Schoolbook
# Century Schoolbook
# Century Schoolbook
# Century Schoolbook
# Century Schoolbook
# Century Schoolbook
# Century Schoolbook
# Century Schoolbook
# Chiller
# Chiller
# Colonna MT
# Colonna MT
# Comic Sans MS
# Comic Sans MS
# Comic Sans MS
# Comic Sans MS
# Comic Sans MS
# Comic Sans MS
# Comic Sans MS
# Comic Sans MS
# Consolas
# Consolas
# Consolas
# Consolas
# Consolas
# Consolas
# Consolas
# Consolas
# Constantia
# Constantia
# Constantia
# Constantia
# Constantia
# Constantia
# Constantia
# Constantia
# Cooper Black
# Cooper Black
# Copperplate Gothic Bold
# Copperplate Gothic Bold
# Copperplate Gothic Light
# Copperplate Gothic Light
# Corbel
# Corbel
# Corbel
# Corbel
# Corbel
# Corbel
# Corbel
# Corbel
# Corbel
# Corbel
# Corbel
# Corbel
# Courier New
# Courier New
# Courier New
# Courier New
# Courier New
# Courier New
# Courier New
# Courier New
# Curlz MT
# Curlz MT
# DFKai-SB
# DFKai-SB
# DejaVu Sans
# DejaVu Sans
# DejaVu Sans
# DejaVu Sans
# DejaVu Sans Display
# DejaVu Sans Mono
# DejaVu Sans Mono
# DejaVu Sans Mono
# DejaVu Sans Mono
# DejaVu Serif
# DejaVu Serif
# DejaVu Serif
# DejaVu Serif
# DejaVu Serif Display
# Droid Serif
# Droid Serif
# Droid Serif
# Droid Serif
# Droid Serif
# Dubai
# Dubai
# Dubai
# Dubai
# Dubai
# Dubai
# Dubai
# Dubai
# Ebrima
# Ebrima
# Ebrima
# Ebrima
# Edwardian Script ITC
# Edwardian Script ITC
# Elephant
# Elephant
# Elephant
# Elephant
# Engravers MT
# Engravers MT
# Eras Bold ITC
# Eras Bold ITC
# Eras Demi ITC
# Eras Demi ITC
# Eras Light ITC
# Eras Light ITC
# Eras Medium ITC
# Eras Medium ITC
# Felix Titling
# Felix Titling
# Footlight MT Light
# Footlight MT Light
# Forte
# Forte
# Franklin Gothic Book
# Franklin Gothic Book
# Franklin Gothic Book
# Franklin Gothic Book
# Franklin Gothic Demi
# Franklin Gothic Demi
# Franklin Gothic Demi
# Franklin Gothic Demi
# Franklin Gothic Demi Cond
# Franklin Gothic Demi Cond
# Franklin Gothic Heavy
# Franklin Gothic Heavy
# Franklin Gothic Heavy
# Franklin Gothic Heavy
# Franklin Gothic Medium
# Franklin Gothic Medium
# Franklin Gothic Medium
# Franklin Gothic Medium
# Franklin Gothic Medium Cond
# Franklin Gothic Medium Cond
# Freestyle Script
# Freestyle Script
# French Script MT
# French Script MT
# Gabriola
# Gabriola
# Gadugi
# Gadugi
# Gadugi
# Gadugi
# Garamond
# Garamond
# Garamond
# Garamond
# Garamond
# Garamond
# Georgia
# Georgia
# Georgia
# Georgia
# Georgia
# Georgia
# Georgia
# Georgia
# Gigi
# Gigi
# Gill Sans MT
# Gill Sans MT
# Gill Sans MT
# Gill Sans MT
# Gill Sans MT
# Gill Sans MT
# Gill Sans MT
# Gill Sans MT
# Gill Sans MT Condensed
# Gill Sans MT Condensed
# Gill Sans MT Ext Condensed Bold
# Gill Sans MT Ext Condensed Bold
# Gill Sans Ultra Bold
# Gill Sans Ultra Bold
# Gill Sans Ultra Bold Condensed
# Gill Sans Ultra Bold Condensed
# Gloucester MT Extra Condensed
# Gloucester MT Extra Condensed
# Goudy Old Style
# Goudy Old Style
# Goudy Old Style
# Goudy Old Style
# Goudy Old Style
# Goudy Old Style
# Goudy Stout
# Goudy Stout
# HP Simplified
# HP Simplified
# HP Simplified
# HP Simplified
# HP Simplified
# HP Simplified
# HP Simplified
# HP Simplified
# HP Simplified
# HP Simplified
# HP Simplified
# HP Simplified
# HP Simplified
# Haettenschweiler
# Haettenschweiler
# Harlow Solid Italic
# Harlow Solid Italic
# Harrington
# Harrington
# High Tower Text
# High Tower Text
# High Tower Text
# High Tower Text
# HoloLens MDL2 Assets
# HoloLens MDL2 Assets
# Impact
# Impact
# Imprint MT Shadow
# Imprint MT Shadow
# Indie Flower
# Indie Flower
# Informal Roman
# Informal Roman
# Ink Free
# Ink Free
# Javanese Text
# Javanese Text
# Jokerman
# Jokerman
# Juice ITC
# Juice ITC
# Kievit Offc Pro
# Kievit Offc Pro
# Kristen ITC
# Kristen ITC
# Kunstler Script
# Kunstler Script
# Leelawadee UI
# Leelawadee UI
# Leelawadee UI
# Leelawadee UI
# Leelawadee UI
# Leelawadee UI
# Lobster
# Lobster
# Lucida Bright
# Lucida Bright
# Lucida Bright
# Lucida Bright
# Lucida Bright
# Lucida Bright
# Lucida Bright
# Lucida Bright
# Lucida Calligraphy
# Lucida Calligraphy
# Lucida Console
# Lucida Console
# Lucida Fax
# Lucida Fax
# Lucida Fax
# Lucida Fax
# Lucida Fax
# Lucida Fax
# Lucida Fax
# Lucida Fax
# Lucida Handwriting
# Lucida Handwriting
# Lucida Sans
# Lucida Sans
# Lucida Sans
# Lucida Sans
# Lucida Sans
# Lucida Sans
# Lucida Sans
# Lucida Sans
# Lucida Sans Typewriter
# Lucida Sans Typewriter
# Lucida Sans Typewriter
# Lucida Sans Typewriter
# Lucida Sans Typewriter
# Lucida Sans Typewriter
# Lucida Sans Typewriter
# Lucida Sans Typewriter
# Lucida Sans Unicode
# Lucida Sans Unicode
# MS Gothic
# MS Gothic
# MS Outlook
# MS Outlook
# MS Reference Sans Serif
# MS Reference Sans Serif
# MS Reference Specialty
# MS Reference Specialty
# MT Extra
# MT Extra
# MV Boli
# MV Boli
# Magneto
# Magneto
# Maiandra GD
# Maiandra GD
# Malgun Gothic
# Malgun Gothic
# Malgun Gothic
# Malgun Gothic
# Malgun Gothic
# Malgun Gothic
# Marlett
# Matura MT Script Capitals
# Matura MT Script Capitals
# Microsoft Himalaya
# Microsoft Himalaya
# Microsoft JhengHei
# Microsoft JhengHei
# Microsoft JhengHei
# Microsoft JhengHei
# Microsoft JhengHei
# Microsoft JhengHei
# Microsoft New Tai Lue
# Microsoft New Tai Lue
# Microsoft New Tai Lue
# Microsoft New Tai Lue
# Microsoft PhagsPa
# Microsoft PhagsPa
# Microsoft PhagsPa
# Microsoft PhagsPa
# Microsoft Sans Serif
# Microsoft Sans Serif
# Microsoft Tai Le
# Microsoft Tai Le
# Microsoft Tai Le
# Microsoft Tai Le
# Microsoft YaHei
# Microsoft YaHei
# Microsoft YaHei
# Microsoft YaHei
# Microsoft YaHei
# Microsoft YaHei
# Microsoft Yi Baiti
# Microsoft Yi Baiti
# MingLiU
# MingLiU
# MingLiU-ExtB
# MingLiU-ExtB
# Mistral
# Mistral
# Modern No. 20
# Modern No. 20
# Mongolian Baiti
# Mongolian Baiti
# Monotype Corsiva
# Monotype Corsiva
# Myanmar Text
# Myanmar Text
# Myanmar Text
# Myanmar Text
# Niagara Engraved
# Niagara Engraved
# Niagara Solid
# Niagara Solid
# Nirmala UI
# Nirmala UI
# Nirmala UI
# Nirmala UI
# Nirmala UI
# Nirmala UI
# OCR A Extended
# OCR A Extended
# Old English Text MT
# Old English Text MT
# Onyx
# Onyx
# Open Sans
# Open Sans
# Open Sans
# Open Sans
# Open Sans
# Palace Script MT
# Palace Script MT
# Palatino Linotype
# Palatino Linotype
# Palatino Linotype
# Palatino Linotype
# Palatino Linotype
# Palatino Linotype
# Palatino Linotype
# Palatino Linotype
# Papyrus
# Papyrus
# Parchment
# Parchment
# Perpetua
# Perpetua
# Perpetua
# Perpetua
# Perpetua
# Perpetua
# Perpetua
# Perpetua
# Perpetua Titling MT
# Perpetua Titling MT
# Perpetua Titling MT
# Perpetua Titling MT
# Playbill
# Playbill
# Poiret One
# Poiret One
# Poor Richard
# Poor Richard
# Pristina
# Pristina
# Rage Italic
# Rage Italic
# Raleway
# Raleway
# Raleway
# Ravie
# Ravie
# Roboto
# Roboto
# Roboto
# Roboto
# Roboto
# Roboto Condensed
# Roboto Condensed
# Roboto Condensed
# Roboto Condensed
# Roboto Condensed
# Roboto Slab
# Roboto Slab
# Roboto Slab
# Rockwell
# Rockwell
# Rockwell
# Rockwell
# Rockwell
# Rockwell
# Rockwell
# Rockwell
# Rockwell Condensed
# Rockwell Condensed
# Rockwell Condensed
# Rockwell Condensed
# Rockwell Extra Bold
# Rockwell Extra Bold
# STIXGeneral
# STIXGeneral
# STIXGeneral
# STIXGeneral
# STIXNonUnicode
# STIXNonUnicode
# STIXNonUnicode
# STIXNonUnicode
# STIXSizeFiveSym
# STIXSizeFourSym
# STIXSizeFourSym
# STIXSizeOneSym
# STIXSizeOneSym
# STIXSizeThreeSym
# STIXSizeThreeSym
# STIXSizeTwoSym
# STIXSizeTwoSym
# Script MT Bold
# Script MT Bold
# Segoe MDL2 Assets
# Segoe MDL2 Assets
# Segoe Print
# Segoe Print
# Segoe Print
# Segoe Print
# Segoe Script
# Segoe Script
# Segoe Script
# Segoe Script
# Segoe UI
# Segoe UI
# Segoe UI
# Segoe UI
# Segoe UI
# Segoe UI
# Segoe UI
# Segoe UI
# Segoe UI
# Segoe UI
# Segoe UI
# Segoe UI
# Segoe UI
# Segoe UI
# Segoe UI
# Segoe UI
# Segoe UI
# Segoe UI
# Segoe UI
# Segoe UI
# Segoe UI
# Segoe UI
# Segoe UI
# Segoe UI
# Segoe UI Emoji
# Segoe UI Emoji
# Segoe UI Historic
# Segoe UI Historic
# Segoe UI Symbol
# Segoe UI Symbol
# Showcard Gothic
# Showcard Gothic
# SimSun
# SimSun
# SimSun-ExtB
# SimSun-ExtB
# Sitka Small
# Sitka Small
# Sitka Small
# Sitka Small
# Sitka Small
# Sitka Small
# Sitka Small
# Sitka Small
# Snap ITC
# Snap ITC
# Stencil
# Stencil
# Sylfaen
# Sylfaen
# Symbol
# Symbol
# Tahoma
# Tahoma
# Tahoma
# Tahoma
# Taipei Sans TC Beta
# Tempus Sans ITC
# Tempus Sans ITC
# Times New Roman
# Times New Roman
# Times New Roman
# Times New Roman
# Times New Roman
# Times New Roman
# Times New Roman
# Times New Roman
# Trebuchet MS
# Trebuchet MS
# Trebuchet MS
# Trebuchet MS
# Trebuchet MS
# Trebuchet MS
# Trebuchet MS
# Trebuchet MS
# Tw Cen MT
# Tw Cen MT
# Tw Cen MT
# Tw Cen MT
# Tw Cen MT
# Tw Cen MT
# Tw Cen MT
# Tw Cen MT
# Tw Cen MT Condensed
# Tw Cen MT Condensed
# Tw Cen MT Condensed
# Tw Cen MT Condensed
# Tw Cen MT Condensed Extra Bold
# Tw Cen MT Condensed Extra Bold
# Verdana
# Verdana
# Verdana
# Verdana
# Verdana
# Verdana
# Verdana
# Verdana
# Viner Hand ITC
# Viner Hand ITC
# Vivaldi
# Vivaldi
# Vladimir Script
# Vladimir Script
# Webdings
# Webdings
# Wide Latin
# Wide Latin
# Wingdings
# Wingdings
# Wingdings 2
# Wingdings 2
# Wingdings 3
# Wingdings 3
# Yu Gothic
# Yu Gothic
# Yu Gothic
# Yu Gothic
# Yu Gothic
# Yu Gothic
# Yu Gothic
# Yu Gothic
# cmb10
# cmex10
# cmmi10
# cmr10
# cmss10
# cmsy10
# cmtt10

# %%
import matplotlib.pyplot as plt
 
plt.rcParams['font.sans-serif'] = ['Taipei Sans TC Beta']
 
sales = [100,80,50]
x_labels = ['A品牌','B品牌','C品牌']
 
plt.bar(x_labels,sales)
plt.show()

# %% [markdown]
# # (2) Plotting

# %% [markdown]
# ## 2-1 Accuracy of All vocs, TF top 200, TF-IDF top 200

# %%
# Figure 01: Accuracy of All vocs, TF top 200, TF-IDF top 200

import matplotlib.pyplot as plt
import numpy as np

labels = ['TF top 200 (200 features)', 'TF-IDF top 200 (200 features)', 'All vocs (4102 features)']
Test_LR_N_filter = [79.78, 78.67, 83.22]
Test_SVM_N_filter = [81.22, 80.45, 81.67]
Test_RF_N_filter = [78.67, 80.67, 71.89]
Test_XGBoost_N_filter = [81.22, 84.44, 85.56]
# Baseline = [68.92] * 5

x = np.arange(len(labels))  # the label locations
y = np.arange(0, 101, 10)
width = 0.2  # the width of the bars

fig, ax = plt.subplots(figsize=(13, 7))
ax.grid()
ax.axis([-0.49, 2.5, 0, 90]) 

rects01 = ax.bar(x - width*3/2, Test_LR_N_filter, width, label='LR')
rects02 = ax.bar(x - width/2, Test_SVM_N_filter, width, label='SVM')
rects03 = ax.bar(x + width/2, Test_RF_N_filter, width, label='RF')
rects04 = ax.bar(x + width*3/2, Test_XGBoost_N_filter, width, label='XGBoost')

# Baseline = [68.92] * 6
# ax.plot(range(-1,5) , Baseline, ls='--', linewidth=2.2, color= 'dimgrey', label="Baseline (68.92%)")  

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Accuracy (%)', fontsize = 17)
ax.set_xlabel('Feautre extraction method', fontsize = 17)
ax.set_title('Accuracy of All vocs, TF top 200, TF-IDF top 200', fontsize = 21)

Baseline = [68.92] * 6
line01 = ax.plot(range(-1,5) , Baseline, ls='--', linewidth=2.2, color= 'dimgrey', label="Baseline (68.92%)")  

ax.set_yticks(y) 
ax.set_yticklabels(y, fontsize=15) 
ax.set_xticks(x)
ax.set_xticklabels(labels, fontsize = 15)

ax.bar_label(rects01, padding=3, fontsize = 15)
ax.bar_label(rects02, padding=3, fontsize = 15)
ax.bar_label(rects03, padding=3, fontsize = 15)
ax.bar_label(rects04, padding=3, fontsize = 15)

ax.legend(loc = 'lower center', fontsize = 17, shadow = True) 
# ax.legend(handles = [rects01, rects02, rects03, rects04, line01], labels = ['LR', 'SVM', 'RF', 'XGBoost', 'Baseline (68.92%)'], loc = 'center right', fontsize = 15) 

fig.tight_layout()
plt.show()


'''
plt.plot(range(-1,4) , Baseline, ls='--', linewidth=2.2, color= 'dimgrey', label="Baseline")  

plt.xticks(range(3), labels = features, fontsize = 24)  
plt.yticks(np.arange(70, 95, 5), fontsize = 24)

plt.ylabel('Accuracy (%)', fontsize = 24)
plt.xlabel('Feautre Extraction Method', fontsize = 24)
plt.title('All vocs, TF top 200, TF-IDF top 200', fontsize = 24)
plt.axis([-0.14, 2.15, 68.2, 87.3]) 

plt.legend(loc = 'center right', fontsize = 24) 
plt.show();
'''
# Out:
# '\nplt.plot(range(-1,4) , Baseline, ls=\'--\', linewidth=2.2, color= \'dimgrey\', label="Baseline")  \n\nplt.xticks(range(3), labels = features, fontsize = 24)  \nplt.yticks(np.arange(70, 95, 5), fontsize = 24)\n\nplt.ylabel(\'Accuracy (%)\', fontsize = 24)\nplt.xlabel(\'Feautre Extraction Method\', fontsize = 24)\nplt.title(\'All vocs, TF top 200, TF-IDF top 200\', fontsize = 24)\nplt.axis([-0.14, 2.15, 68.2, 87.3]) \n\nplt.legend(loc = \'center right\', fontsize = 24) \nplt.show();\n'

# %%
# Figure 01: Accuracy of All vocs, TF top 200, TF-IDF top 200

import matplotlib.pyplot as plt
import numpy as np

labels = ['TF 前 200 大字詞 (200 個特徵)', 'TF-IDF 前 200 大字詞 200 個特徵)', '全部字詞 (4102 個特徵)']
Test_LR_N_filter = [79.78, 78.67, 83.22]
Test_SVM_N_filter = [81.22, 80.45, 81.67]
Test_RF_N_filter = [78.67, 80.67, 71.89]
Test_XGBoost_N_filter = [81.22, 84.44, 85.56]
# Baseline = [68.92] * 5

x = np.arange(len(labels))  # the label locations
y = np.arange(0, 101, 10)
width = 0.2  # the width of the bars

fig, ax = plt.subplots(figsize=(13, 7))
ax.grid()
ax.axis([-0.49, 2.5, 0, 90]) 

rects01 = ax.bar(x - width*3/2, Test_LR_N_filter, width, label='LR')
rects02 = ax.bar(x - width/2, Test_SVM_N_filter, width, label='SVM')
rects03 = ax.bar(x + width/2, Test_RF_N_filter, width, label='RF')
rects04 = ax.bar(x + width*3/2, Test_XGBoost_N_filter, width, label='XGBoost')

# Baseline = [68.92] * 6
# ax.plot(range(-1,5) , Baseline, ls='--', linewidth=2.2, color= 'dimgrey', label="Baseline (68.92%)")  

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('準確率 (%)', fontsize = 20)
ax.set_xlabel('特徵選取方法', fontsize = 20)
ax.set_title('初階特徵篩選方法的準確率', fontsize = 22)

Baseline = [68.92] * 6
line01 = ax.plot(range(-1,5) , Baseline, ls='--', linewidth=2.2, color= 'dimgrey', label="基準線 (68.92%)")  

ax.set_yticks(y) 
ax.set_yticklabels(y, fontsize=19.3) 
ax.set_xticks(x)
ax.set_xticklabels(labels, fontsize = 19.3)

ax.bar_label(rects01, padding=3, fontsize = 18)
ax.bar_label(rects02, padding=3, fontsize = 18)
ax.bar_label(rects03, padding=3, fontsize = 18)
ax.bar_label(rects04, padding=3, fontsize = 18)

ax.legend(loc = 'lower center', fontsize = 20, shadow = True) 
# ax.legend(handles = [rects01, rects02, rects03, rects04, line01], labels = ['LR', 'SVM', 'RF', 'XGBoost', 'Baseline (68.92%)'], loc = 'center right', fontsize = 15) 

fig.tight_layout()
plt.show()

# %% [markdown]
# ## 2-2 N-filter

# %%
# Figure 02: N-Filter of All Models

import matplotlib.pyplot as plt
import numpy as np

test_LR_N_filter = [80.71, 79.44, 82.82, 83.49, 86.44, 86.62, 88.11]
test_SVM_N_filter = [79.73, 82.60, 82.60, 82.75, 82.51, 85.04, 85.07]
test_RF_N_filter = [78.00, 81.91, 81.91, 81.62, 83.13, 81.15, 81.00]
test_XGBoost_N_filter = [79.47, 79.76, 79.76, 79.29, 83.89, 84.27, 85.11]

labels = ['4.5- (5 f)', '4- (8 f)', '3.5- (18 f)', '3- (36 f)', '2.5- (51 f)', '2- (118 f)', '1.7- (210 f)']

Baseline = [68.92] * 9

x = np.arange(7)
y = np.arange(70, 95, 5)

fig, ax = plt.subplots(figsize=(13, 7))
ax.grid()

ax.plot(range(7) , test_LR_N_filter, ls='-', lw=2.5, marker='o', mew=4.5 , label="LR") # color= 'tab:blue'
ax.plot(range(7) , test_SVM_N_filter, ls='--', lw=2.5, marker='s', mew=4.5 , label="SVM")
ax.plot(range(7) , test_RF_N_filter, ls='-.', lw=2.5, marker='v', mew=4.5 , label="RF")
ax.plot(range(7) , test_XGBoost_N_filter, ls='--', lw=2.5, marker='s', mew=4.5 , label="XGBoost") # color= 'tab:orange', mec='tab:orange'

'''
plt.plot(range(4) , TF200, ls='--', lw=2.5, color= 'darkorange', marker='s', mec='darkorange', mew=4.5 , label="TF 200")  
plt.plot(range(4) , TFIDF200, ls='-.', lw=2.5, color= 'tab:green', marker='v', mec='tab:green', mew=4.5 , label="TF-IDF 200")  
'''
ax.plot(range(-1,8) , Baseline, ls='--', linewidth=2.2, color= 'dimgrey', label="Baseline (68.92%)")  

ax.set_title('Accuracy of N-filters', fontsize = 21)
ax.set_ylabel('Accuracy (%)', fontsize = 17)
ax.set_xlabel('N-filter (N- = N-filter; f = feature)', fontsize = 17)
ax.axis([-0.20, 6.2, 68.2, 90]) 

ax.set_yticks(y) 
ax.set_yticklabels(y, fontsize=15) 
ax.set_xticks(x)
ax.set_xticklabels(labels=labels, fontsize = 15)

label = "{:.2f}".format(88.11)
ax.annotate(label, # this is the text
              (6,88.11), # these are the coordinates to position the label
              textcoords="offset points", # how to position the text
              xytext=(0,12), # distance from text to points (x,y)
              fontsize = 15, 
              ha='center') # horizontal alignment can be left, right or center

label = "{:.2f}".format(83.49)
ax.annotate(label, # this is the text
              (3,83.49), # these are the coordinates to position the label
              textcoords="offset points", # how to position the text
              xytext=(3,15), # distance from text to points (x,y)
              fontsize = 15, 
              ha='center') # horizontal alignment can be left, right or center

ax.legend(loc = 'lower center', fontsize = 17) 
plt.show();

# %%
# Figure 02: N-Filter of All Models

import matplotlib.pyplot as plt
import numpy as np
'''
training 80.79, 78.51, 77.70
test 82.22, 77.78, 77.78
'''
test_LR_N_filter = [80.71, 79.44, 82.82, 83.49, 86.44, 86.62, 88.11]
test_SVM_N_filter = [79.73, 82.60, 82.60, 82.75, 82.51, 85.04, 85.07]
test_RF_N_filter = [78.00, 81.91, 81.91, 81.62, 83.13, 81.15, 81.00]
test_XGBoost_N_filter = [79.47, 79.76, 79.76, 79.29, 83.89, 84.27, 85.11]


labels = ['4.5- (5 f)', '4- (8 f)', '3.5- (18 f)', '3- (36 f)', '2.5- (51 f)', '2- (118 f)', '1.7- (210 f)']
Baseline = [68.92] * 9

x = np.arange(7)
y = np.arange(70, 95, 5)

fig, ax = plt.subplots(figsize=(13, 7))
ax.grid()

ax.plot(range(7) , test_LR_N_filter, ls='-', lw=2.5, marker='o', mew=4.5 , label="LR") # color= 'tab:blue'
ax.plot(range(7) , test_SVM_N_filter, ls='--', lw=2.5, marker='s', mew=4.5 , label="SVM")
ax.plot(range(7) , test_RF_N_filter, ls='-.', lw=2.5, marker='v', mew=4.5 , label="RF")
ax.plot(range(7) , test_XGBoost_N_filter, ls='--', lw=2.5, marker='s', mew=4.5 , label="XGBoost") # color= 'tab:orange', mec='tab:orange'

'''
plt.plot(range(4) , TF200, ls='--', lw=2.5, color= 'darkorange', marker='s', mec='darkorange', mew=4.5 , label="TF 200")  
plt.plot(range(4) , TFIDF200, ls='-.', lw=2.5, color= 'tab:green', marker='v', mec='tab:green', mew=4.5 , label="TF-IDF 200")  
'''
ax.plot(range(-1,8) , Baseline, ls='--', linewidth=2.2, color= 'dimgrey', label="基準線 (68.92%)")  

ax.set_title('N 倍數指標的準確率', fontsize = 22)
ax.set_ylabel('準確率 (%)', fontsize = 20)
ax.set_xlabel('N 倍數指標 (N- = N 倍數指標；f = 特徵)', fontsize = 20)
ax.axis([-0.20, 6.2, 68.2, 90])  

ax.set_yticks(y) 
ax.set_yticklabels(y, fontsize=19) 
ax.set_xticks(x)
ax.set_xticklabels(labels=labels, fontsize = 19)

label = "{:.2f}".format(88.11)
ax.annotate(label, # this is the text
              (6,88.11), # these are the coordinates to position the label
              textcoords="offset points", # how to position the text
              xytext=(0,12), # distance from text to points (x,y)
              fontsize = 18, 
              ha='center') # horizontal alignment can be left, right or center

label = "{:.2f}".format(83.49)
ax.annotate(label, # this is the text
              (3,83.49), # these are the coordinates to position the label
              textcoords="offset points", # how to position the text
              xytext=(3,15), # distance from text to points (x,y)
              fontsize = 18, 
              ha='center') # horizontal alignment can be left, right or center

ax.legend(loc = 'lower center', fontsize = 20) 
plt.show();

# %%
'''
# Add Labels and Text to Matplotlib Plots: Annotation Examples
# https://queirozf.com/entries/add-labels-and-text-to-matplotlib-plots-annotation-examples

import matplotlib.pyplot as plt
import numpy as np

plt.clf()

# using some dummy data for this example
xs = np.arange(0,10,1)
ys = np.random.normal(loc=3, scale=0.4, size=10)

# 'bo-' means blue color, round points, solid lines
plt.plot(xs,ys,'bo-')

# zip joins x and y coordinates in pairs
for x,y in zip(xs,ys):

    label = "{:.2f}".format(y)

    plt.annotate(label, # this is the text
                 (x,y), # these are the coordinates to position the label
                 textcoords="offset points", # how to position the text
                 xytext=(0,10), # distance from text to points (x,y)
                 ha='center') # horizontal alignment can be left, right or center

plt.show()
'''

# %% [markdown]
# ## 2-3 Linear dimension reduction: PCA

# %%
# Figure 03: Linear Dimension Reudction - PCA

import matplotlib.pyplot as plt
import numpy as np
'''
training 80.79, 78.51, 77.70
test 82.22, 77.78, 77.78
'''

test_LR_PCA = [76.78, 75.82, 75.98, 75.22, 77.18]
test_SVM_PCA = [78.33, 77.71, 75.93, 75.71, 78.47]
test_RF_PCA = [74.18, 73.42, 72.33, 71.04, 69.05]
test_XGBoost_PCA = [77.47, 76.84, 77.36, 76.00, 75.07]

labels = ['80 % (arounf 31 f)', '85 % (around 45 f)', '90 % (around 66 f)', '95 % (around 101 f)', '99 % (around 153 f)']

Baseline = [68.92] * 7

x = np.arange(5)
y = np.arange(70, 81, 5)

fig, ax = plt.subplots(figsize=(12.5, 7.5))
ax.grid()

ax.plot(range(5) , test_LR_PCA, ls='-', lw=2.5, marker='o', mew=4.5 , label="LR") # color= 'tab:blue'
ax.plot(range(5) , test_SVM_PCA, ls='--', lw=2.5, marker='s', mew=4.5 , label="SVM")
ax.plot(range(5) , test_RF_PCA, ls='-.', lw=2.5, marker='v', mew=4.5 , label="RF")
ax.plot(range(5) , test_XGBoost_PCA, ls='--', lw=2.5, marker='s', mew=4.5 , label="XGBoost") # color= 'tab:orange', mec='tab:orange'

'''
plt.plot(range(4) , TF200, ls='--', lw=2.5, color= 'darkorange', marker='s', mec='darkorange', mew=4.5 , label="TF 200")  
plt.plot(range(4) , TFIDF200, ls='-.', lw=2.5, color= 'tab:green', marker='v', mec='tab:green', mew=4.5 , label="TF-IDF 200")  
'''
ax.plot(range(-1,6) , Baseline, ls='--', linewidth=2.2, color= 'dimgrey', label="Baseline (68.92%)")  

ax.set_title('Accuracy of PCA', fontsize = 22)
ax.set_ylabel('Accuracy (%)', fontsize = 20)
ax.set_xlabel('Explained variance ratio (f = features)', fontsize = 20)
ax.axis([-0.25, 4.25, 68.2, 80.0]) 

ax.set_yticks(y) 
ax.set_yticklabels(y, fontsize=19) 
ax.set_xticks(x)
ax.set_xticklabels(labels=labels, fontsize = 19)

label = "{:.2f}".format(78.47)
ax.annotate(label, # this is the text
              (4,78.47), # these are the coordinates to position the label
              textcoords="offset points", # how to position the text
              xytext=(0,15), # distance from text to points (x,y)
              fontsize = 18, 
              ha='center') # horizontal alignment can be left, right or center

label = "{:.2f}".format(77.18)
ax.annotate(label, # this is the text
              (4,77.18), # these are the coordinates to position the label
              textcoords="offset points", # how to position the text
              xytext=(0,-30), # distance from text to points (x,y)
              fontsize = 18, 
              ha='center') # horizontal alignment can be left, right or center

ax.legend(loc = 'lower left', fontsize = 20) 
plt.show();

# %%
# Figure 03: Linear Dimension Reudction - PCA

import matplotlib.pyplot as plt
import numpy as np
'''
training 80.79, 78.51, 77.70
test 82.22, 77.78, 77.78
'''
test_LR_PCA = [76.78, 75.82, 75.98, 75.22, 77.18]
test_SVM_PCA = [78.33, 77.71, 75.93, 75.71, 78.47]
test_RF_PCA = [74.18, 73.42, 72.33, 71.04, 69.05]
test_XGBoost_PCA = [77.47, 76.84, 77.36, 76.00, 75.07]

labels = ['80 % (約 31 個特徵)', '85 % (約 45 個特徵)', '90 % (約 66 個特徵)', '95 % (約 101 個特徵)', '99 % (約 153 個特徵)']
Baseline = [68.92] * 7

x = np.arange(5)
y = np.arange(70, 81, 5)

fig, ax = plt.subplots(figsize=(12.5, 7.5))
ax.grid()

ax.plot(range(5) , test_LR_PCA, ls='-', lw=2.5, marker='o', mew=4.5 , label="LR") # color= 'tab:blue'
ax.plot(range(5) , test_SVM_PCA, ls='--', lw=2.5, marker='s', mew=4.5 , label="SVM")
ax.plot(range(5) , test_RF_PCA, ls='-.', lw=2.5, marker='v', mew=4.5 , label="RF")
ax.plot(range(5) , test_XGBoost_PCA, ls='--', lw=2.5, marker='s', mew=4.5 , label="XGBoost") # color= 'tab:orange', mec='tab:orange'

'''
plt.plot(range(4) , TF200, ls='--', lw=2.5, color= 'darkorange', marker='s', mec='darkorange', mew=4.5 , label="TF 200")  
plt.plot(range(4) , TFIDF200, ls='-.', lw=2.5, color= 'tab:green', marker='v', mec='tab:green', mew=4.5 , label="TF-IDF 200")  
'''
ax.plot(range(-1,6) , Baseline, ls='--', linewidth=2.2, color= 'dimgrey', label="基準線 (68.92%)")  

ax.set_title('線性降維方法的準確率：PCA', fontsize = 20.2)
ax.set_ylabel('準確率 (%)', fontsize = 19)
ax.set_xlabel('可解釋變異率', fontsize = 19)
ax.axis([-0.25, 4.25, 68.2, 80.0]) 

ax.set_yticks(y) 
ax.set_yticklabels(y, fontsize=16.1) 
ax.set_xticks(x)
ax.set_xticklabels(labels=labels, fontsize = 16.1)

label = "{:.2f}".format(78.47)
ax.annotate(label, # this is the text
              (4,78.47), # these are the coordinates to position the label
              textcoords="offset points", # how to position the text
              xytext=(0,15), # distance from text to points (x,y)
              fontsize = 18, 
              ha='center') # horizontal alignment can be left, right or center

label = "{:.2f}".format(77.18)
ax.annotate(label, # this is the text
              (4,77.18), # these are the coordinates to position the label
              textcoords="offset points", # how to position the text
              xytext=(0,-30), # distance from text to points (x,y)
              fontsize = 18, 
              ha='center') # horizontal alignment can be left, right or center

ax.legend(loc = 'lower left', fontsize = 19) 
plt.show();

# %% [markdown]
# ## 2-4 Non-linear dimension reduction: kernel PCA

# %%
# Figure 04: Non-linear Dimension reduction - KPCA

import matplotlib.pyplot as plt
import numpy as np
'''
training 80.79, 78.51, 77.70
test 82.22, 77.78, 77.78
'''

test_LR_PCA = [70.84, 71.27, 71.22, 70.84]
test_SVM_PCA = [71.95, 71.49, 71.96, 72.36]
test_RF_PCA = [69.05, 69.05, 68.89, 68.89]
test_XGBoost_PCA = [73.18, 71.91, 70.53, 70.02]

labels = ['50 features', '100 features', '150 features', '177 features']

Baseline = [68.92] * 6

x = np.arange(4)
y = np.arange(65, 76, 5)

fig, ax = plt.subplots(figsize=(10, 7.5))
ax.grid()

ax.plot(range(4) , test_LR_PCA, ls='-', lw=2.5, marker='o', mew=4.5 , label="LR") # color= 'tab:blue'
ax.plot(range(4) , test_SVM_PCA, ls='--', lw=2.5, marker='s', mew=4.5 , label="SVM")
ax.plot(range(4) , test_RF_PCA, ls='-.', lw=2.5, marker='v', mew=4.5 , label="RF")
ax.plot(range(4) , test_XGBoost_PCA, ls='--', lw=2.5, marker='s', mew=4.5 , label="XGBoost") # color= 'tab:orange', mec='tab:orange'

'''
plt.plot(range(4) , TF200, ls='--', lw=2.5, color= 'darkorange', marker='s', mec='darkorange', mew=4.5 , label="TF 200")  
plt.plot(range(4) , TFIDF200, ls='-.', lw=2.5, color= 'tab:green', marker='v', mec='tab:green', mew=4.5 , label="TF-IDF 200")  
'''
ax.plot(range(-1,5) , Baseline, ls='--', linewidth=2.2, color= 'dimgrey', label="Baseline (68.92%)")  

ax.set_title('Accuracy of kernel PCA', fontsize = 21)
ax.set_ylabel('Accuracy (%)', fontsize = 17)
ax.set_xlabel('Features of kernel PCA', fontsize = 17)
ax.axis([-0.14, 3.2, 64.1, 75.0]) 

ax.set_yticks(y) 
ax.set_yticklabels(y, fontsize=15) 
ax.set_xticks(x)
ax.set_xticklabels(labels=labels, fontsize = 15)

label = "{:.2f}".format(73.18)
ax.annotate(label, # this is the text
              (0,73.18), # these are the coordinates to position the label
              textcoords="offset points", # how to position the text
              xytext=(0,14), # distance from text to points (x,y)
              fontsize = 17, 
              ha='center') # horizontal alignment can be left, right or center

label = "{:.2f}".format(71.27)
ax.annotate(label, # this is the text
              (1,71.27), # these are the coordinates to position the label
              textcoords="offset points", # how to position the text
              xytext=(0,-26), # distance from text to points (x,y)
              fontsize = 17, 
              ha='center') # horizontal alignment can be left, right or center

ax.legend(loc = 'lower center', fontsize = 17) 
plt.show();

# %%
# Figure 04: Non-linear Dimension reduction - KPCA

import matplotlib.pyplot as plt
import numpy as np


test_LR_PCA = [70.84, 71.27, 71.22, 70.84]
test_SVM_PCA = [71.95, 71.49, 71.96, 72.36]
test_RF_PCA = [69.05, 69.05, 68.89, 68.89]
test_XGBoost_PCA = [73.18, 71.91, 70.53, 70.02]

labels = ['50 個特徵', '100 個特徵', '150 個特徵', '177 個特徵']
Baseline = [68.92] * 6

x = np.arange(4)
y = np.arange(65, 76, 5)

fig, ax = plt.subplots(figsize=(10, 7.3))
ax.grid()

ax.plot(range(4) , test_LR_PCA, ls='-', lw=2.5, marker='o', mew=4.5 , label="LR") # color= 'tab:blue'
ax.plot(range(4) , test_SVM_PCA, ls='--', lw=2.5, marker='s', mew=4.5 , label="SVM")
ax.plot(range(4) , test_RF_PCA, ls='-.', lw=2.5, marker='v', mew=4.5 , label="RF")
ax.plot(range(4) , test_XGBoost_PCA, ls='--', lw=2.5, marker='s', mew=4.5 , label="XGBoost") # color= 'tab:orange', mec='tab:orange'

'''
plt.plot(range(4) , TF200, ls='--', lw=2.5, color= 'darkorange', marker='s', mec='darkorange', mew=4.5 , label="TF 200")  
plt.plot(range(4) , TFIDF200, ls='-.', lw=2.5, color= 'tab:green', marker='v', mec='tab:green', mew=4.5 , label="TF-IDF 200")  
'''
ax.plot(range(-1,5) , Baseline, ls='--', linewidth=2.2, color= 'dimgrey', label="Baseline (68.92%)")  

ax.set_title('非線性降維方法的準確率：kernel PCA', fontsize = 21)
ax.set_ylabel('準確率 (%)', fontsize = 20)
ax.set_xlabel('特徵數量', fontsize = 20)
ax.axis([-0.18, 3.2, 64.1, 75.0]) 

ax.set_yticks(y) 
ax.set_yticklabels(y, fontsize=18) 
ax.set_xticks(x)
ax.set_xticklabels(labels=labels, fontsize = 19)

label = "{:.2f}".format(73.18)
ax.annotate(label, # this is the text
              (0,73.18), # these are the coordinates to position the label
              textcoords="offset points", # how to position the text
              xytext=(0,14), # distance from text to points (x,y)
              fontsize = 18, 
              ha='center') # horizontal alignment can be left, right or center

label = "{:.2f}".format(71.27)
ax.annotate(label, # this is the text
              (1,71.27), # these are the coordinates to position the label
              textcoords="offset points", # how to position the text
              xytext=(0,-26), # distance from text to points (x,y)
              fontsize = 18, 
              ha='center') # horizontal alignment can be left, right or center

ax.legend(loc = 'lower center', fontsize = 20) 
plt.show();
